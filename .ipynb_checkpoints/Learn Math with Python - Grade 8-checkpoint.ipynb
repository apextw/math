# %% [markdown]
# # Learn Math with Python
# ## Grade 8

# %% [markdown]
# ### Ch 1 Expressions, Equations and Functions
#
# #### What is an "Equation"?
# Equation is a statement that "something = something". For example: $ 5x = 10 $
#
#
# [Know more about Symbolic Python](https://github.com/sympy/sympy/wiki)

# %%
################################################################################
# Evaluate the equation
# Author: stevenlee, tw.steven@gmail.com
################################################################################
from sympy import *

x = Symbol('x')

eq = Eq(5*x,10)  # 5x = 10
solve(eq,x)
# Out:
# [2]

# %% [markdown]
# #### What is a "Function"?
# If you have an input x and an output y, then we may say y is function of x. And write as $ y = f(x) $
#
# <img src="./svg/function.svg" />
#
# Constant Function:
#
# $y = a$
#
# Linear Function:
#
# $ y = ax $
#
# $ y = ax + b$

# %%
################################################################################
# Let's see the linear functions in XY plane
# Author: stevenlee, tw.steven@gmail.com
################################################################################
# Import necessary modules:
# Numpy is for fundamental science computing. http://www.numpy.org/
# Matplotlib is for generating figures. https://matplotlib.org/
import numpy as np
import matplotlib.pyplot as plt

# Prepare the data x = [-10 -9.9 -9.8 ... -0.1 0, 0.1 ... 9.8 9.9]
x = np.arange(-10., 10., 0.1) # ask np to generate an array from -10 to 10, with step 0.1 (start, stop, step)

# Prepare different output data
y_constant = 0*x + 5                          # horizontal line y = 5
y_linear = 2*x                                # y = 2x

# Plot to figure
plt.figure(figsize=(8, 6), dpi=80)
plt.title('Constant and Linear Functions')    # Title of 1st subplot
plt.plot(x, y_constant,'r',x, y_linear, 'g')  # Plota red line and green line

plt.text(-8,6,'Constant Function')
plt.text(-4,-10,'Linear Function')
plt.grid(True)                                # Turn on the grid
plt.xlabel('x')                               # X Label
plt.ylabel('output(y)')                       # Y Label
plt.tight_layout()                            # Tight the layout
plt.show()                                    # Show the plot

# %% [markdown]
# **Do you know?**
#
# Evaluate the equation / Simplify the function / Solve the equation ...
#
# **Evaluate**: To find the value of an expression.
#
# **Solve**: To find "the solution"(a set of values) that satisfy the given equation(s).
#
# **Simplify**: Reducing an expression to a briefer form.

# %% [markdown]
# ### Ch2 Solving Linear Equations
#
# If $mx + k = 0$, then $ x = -k/m$
#
# **Try to modify m and k to see how x changed**

# %%
################################################################################
# Evaluate the equation
# Author: stevenlee, tw.steven@gmail.com
################################################################################
from sympy import *
import numpy as np
import matplotlib.pyplot as plt
################################################################################
# mx + k = 0
m = 2
k = 4
################################################################################
# Symbolic Method:
x = Symbol('x')

# Two equations here:
eq = Eq(m*x+k,0)

# res is the result
res = solve(eq,x)
print(res)
# Out:
# [-2]

# %% [markdown]
# ### Ch3 Graphing Linear Equations and Functions
#
# **Slope** is the ratio of y over x : $Slope m = y/x$
#
# Or, when x increase 1, how much y will increase.
#
# **Offset** is lifting the line in y direction. Offset is the offset from (0,0) to (0,k)
#
# $ y = slope * x + offset $ or $ y = mx + k$
#
# *Slope and Offset are indepentant*
#
# Try to modify the following plot:
# 1. Offset the line
# 2. Change slope

# %%
################################################################################
# Graphing the equations
# Author: stevenlee, tw.steven@gmail.com
################################################################################
from sympy import *
import numpy as np
import matplotlib.pyplot as plt
################################################################################
# y1 = m1 * x + k1
m1 = 2
k1 = 0
# y2 = m2 * x + k2
m2 = 0
k2 = 5
################################################################################
# Symbolic Method:
x = Symbol('x')
y = Symbol('y')

# Two equations here:
eq1 = Eq(y, m1*x+k1)
eq2 = Eq(y, m2*x+k2)

# res is the result
res = solve([eq1, eq2],(x,y))
x0 = Float(res[x])
y0 = Float(res[y])

################################################################################
# Numerical Method:
# Prepare the data x = [-10 -9.9 -9.8 ... -0.1 0, 0.1 ... 9.8 9.9]
x_ = np.arange(-10., 10., 0.1) # ask np to generate an array from -10 to 10, with step 0.1 (start, stop, step)

# Two equations here:
y_eq1 = m1*x_ + k1
y_eq2 = m2*x_ + k2

# Plot to figure
plt.figure(figsize=(8, 6), dpi=80)
plt.plot(x_, y_eq1,'r',x_, y_eq2, 'g')  # Plota red line and green line
plt.plot(x0, y0,'bo')
plt.text(x0+0.5,y0+0.5,"({:.2f},{:.2f})".format(x0,y0))
plt.grid(True)                                # Turn on the grid
plt.xlabel('x')                               # X Label
plt.ylabel('y')                               # Y Label
plt.tight_layout()                            # Tight the layout
plt.show()                                    # Show the plot

# %% [markdown]
# ### Ch4 Writing Linear Equations
#
# #### Slope-intercept form
# m: slope
# b: y-intercept
#
# $ y = mx + b$
#
# that is: $ (y-b) = m(x-0)$
#
# $(0,b)$ belongs to the line
#
# #### Point-slope form
# m: slope
# $(x_1,y_1)$ belongs to the line
#
# $ y - y_1 = m (x - x_1)$
#
# $ m = \frac{y - y_1}{x-x_1}$
#
# #### What if I don't know the slope?
# Slope-intercept form or Point-slope form are both slope and a point.
# If I don't know the slope. I need 2 points to define a line.
#
# $ P_0 = (x_0,y_0) $
# $ P_1 = (x_1,y_1) $
#
# If $(x_1 - x_0) ≠ 0$,
#
# $ m = \frac{y_1-y_0}{x_1-x_0} $
#
# $ y - y_0 = m * ( x - x_0) $
#
# $ y = mx + (y_0 - mx_0) $
#
# **What if $(x_1 - x_0) = 0$ ?**
#
# **Given 2 points, draw a line**
#
# Modify the 2 points and observe:

# %%
################################################################################
# Given two points, draw a line
# Author: stevenlee, tw.steven@gmail.com
################################################################################
import numpy as np
import matplotlib.pyplot as plt

ROI = 10.0
STEP = ROI/100
# Given points:
x0,y0 = 2,3
x1,y1 = -2,-3

x_ = np.arange(-ROI, ROI, STEP)
# Equation
if x0 == x1:
    if y0 == y1:
        print("Two points are identical!")
        x_ = x_ * 0
        
    else:
        print("x={}".format(x0))
        y_ = x_
        x_ = y_ * 0 + x0
            
else:
    m = float(y1-y0)/float(x1-x0)
    y_ = m * (x_ - x0) + y0 
    
plt.figure(figsize=(8, 6), dpi=80)
plt.plot(x_, y_, 'g')

plt.grid(True)                                # Turn on the grid
plt.xlabel('x')                               # X Label
plt.ylabel('y')                               # Y Label
plt.tight_layout()                            # Tight the layout
plt.show()                                    # Show the plot

# %% [markdown]
# #### Cartesian Coordinates
#
# Cartesian coordinate system is an "orthogonal" coordinates, in which the coordinate surfaces all meet at right angles.
#
# **René Descartes (1596 - 1650)**
# https://en.wikipedia.org/wiki/Ren%C3%A9_Descartes
#
# <p><a href="https://commons.wikimedia.org/wiki/File:Frans_Hals_-_Portret_van_Ren%C3%A9_Descartes.jpg#/media/File:Frans_Hals_-_Portret_van_Ren%C3%A9_Descartes.jpg"><img src="https://upload.wikimedia.org/wikipedia/commons/7/73/Frans_Hals_-_Portret_van_Ren%C3%A9_Descartes.jpg" alt="Frans Hals - Portret van René Descartes.jpg" height="480" width="392"></a><br>By André Hatala [e.a.] (1997) De eeuw van Rembrandt, Bruxelles: Crédit communal de Belgique, <a href="//commons.wikimedia.org/wiki/Special:BookSources/2-908388-32-4" title="Special:BookSources/2-908388-32-4">ISBN 2-908388-32-4</a>., Public Domain, <a href="https://commons.wikimedia.org/w/index.php?curid=2774313">Link</a></p>

# %% [markdown]
# #### Polar Coordinates
#
# In Cartesian coordinate, a point in a 2-dimension plane is (x,y). It implies the point comprised by 2 factors, horizontal part and vertical part. In fact, 2 dimension means 2 degree of freedom, and you need 2 constraint to limit it as a point.
#
# Polar coordinate is just another "2 factors" way to represent (x,y) point.

# %%
################################################################################
# Given two points, draw a line
# Author: stevenlee, tw.steven@gmail.com
################################################################################
import numpy as np
import matplotlib.pyplot as plt

ROI = 10.0
STEP = ROI/10
# Given points:
x0,y0 = 0,3
x1,y1 = 2,0

x_ = np.arange(-ROI, ROI, STEP)
# Equation
if x0 == x1:
    if y0 == y1:
        print("Two points are identical!")
        x_ = x_ * 0
        
    else:
        print("x={}".format(x0))
        y_ = x_
        x_ = y_ * 0 + x0
            
else:
    m = float(y1-y0)/float(x1-x0)
    y_ = m * (x_ - x0) + y0 
    

theta = np.arctan(y_/x_)
radius = x_*np.cos(theta) + y_*np.sin(theta)
# print(theta)
print(radius)

# plt.figure(figsize=(8, 6), dpi=80)
# plt.plot(x_, y_, 'g')
# plt.plot(radius,theta, 'r')

# plt.grid(True)                                # Turn on the grid
# plt.xlabel('x')                               # X Label
# plt.ylabel('y')                               # Y Label
# plt.tight_layout()                            # Tight the layout
# plt.show()                                    # Show the plot
# Out:
# [-20.59126028 -20.4115776  -20.2319055  -20.05224426 -19.87259419
#  -19.69295559 -19.51332878 -19.33371408 -19.15411183 -18.97452239
#  -18.79494613 -18.61538342 -18.43583467 -18.25630028 -18.07678069
#  -17.89727633 -17.71778767 -17.5383152  -17.35885941 -17.17942083
#  -17.         -16.82059749 -16.6412139  -16.46184984 -16.28250595
#  -16.10318292 -15.92388144 -15.74460225 -15.56534613 -15.38611387
#  -15.20690633 -15.02772438 -14.84856895 -14.66944103 -14.49034161
#  -14.31127178 -14.13223266 -13.95322543 -13.77425134 -13.59531169
#  -13.41640786 -13.23754131 -13.05871357 -12.87992624 -12.70118105
#  -12.52247979 -12.34382437 -12.16521681 -11.98665925 -11.80815396
#  -11.62970335 -11.45130997 -11.27297654 -11.09470594 -10.91650127
#  -10.7383658  -10.56030303 -10.3823167  -10.20441081 -10.02658965
#   -9.8488578   -9.67122019  -9.49368211  -9.31624925  -9.13892773
#   -8.96172416  -8.7846457   -8.60770004  -8.43089556  -8.25424133
#   -8.07774721  -7.90142392  -7.72528317  -7.54933772  -7.37360156
#   -7.19809002  -7.02281995  -6.84780987  -6.67308025  -6.49865371
#   -6.32455532  -6.15081295  -5.97745765  -5.8045241   -5.63205114
#   -5.46008242  -5.28866713  -5.11786088  -4.94772675  -4.77833653
#   -4.60977223  -4.44212787  -4.27551167  -4.11004866  -3.94588393
#   -3.78318649  -3.62215406  -3.46301891  -3.30605505  -3.1515869
#   -3.           2.85175385   2.70739727   2.56758642   2.43310501
#    2.30488611   2.18403297   2.07183494   1.96977156   1.87949461
#    1.80277564   1.74140748   1.69705627   1.6710775    1.6643317
#    1.67705098   1.70880075   1.75855054   1.82482876   1.90591186
#    2.           2.10535033   2.22036033   2.34360833   2.47386338
#    2.61007663   2.7513633    2.89698119   3.04630924   3.19882791
#    3.35410197   3.51176594   3.67151195   3.8330797    3.99624824
#    4.16082924   4.32666153   4.49360657   4.66154481   4.83037266
#    5.           5.17034815   5.34134814   5.51293932   5.68506816
#    5.85768726   6.03075451   6.20423243   6.37808749   6.55228968
#    6.72681202   6.90163024   7.07672241   7.25206867   7.42765104
#    7.60345316   7.77946014   7.95565836   8.13203542   8.3085799
#    8.48528137   8.66213022   8.8391176    9.01623536   9.19347595
#    9.37083241   9.54829828   9.72586757   9.90353472  10.08129456
#   10.25914226  10.43707334  10.61508361  10.79316914  10.97132626
#   11.14955156  11.32784181  11.50619398  11.68460526  11.86307296
#   12.04159458  12.22016776  12.39879026  12.57746     12.75617498
#   12.93493332  13.11373326  13.29257311  13.4714513   13.6503663
#   13.82931669  14.00830111  14.18731828  14.36636697  14.54544602
#   14.72455432  14.90369082  15.0828545   15.26204442  15.44125966]

# %%
################################################################################
# Polar Coordinate
# Author: stevenlee, tw.steven@gmail.com
# Date: 2017.06.19
# Modified the Demo of a line plot on a polar axis from Matplotlib
################################################################################

import numpy as np
import matplotlib.pyplot as plt


# r = np.arange(0, 2, 0.02)
# theta = 2 * np.pi * r

theta = np.arange(-2*np.pi,2*np.pi,0.1)
r1 = 1 - np.sin(theta)
r2 = 1 + np.cos(theta)
r3 = 1 + np.sin(theta)

x = r1 * np.cos(theta)
y = r1 * np.sin(theta)

ax = plt.subplot(121, projection='polar')
ax.plot(theta, r1,'r',alpha=0.5)
ax.plot(theta[60],r1[60],'ro')
ax.plot(theta, r2,'g',alpha=0.5)
ax.plot(theta, r3,'b',alpha=0.5)
ax.set_rmax(2)
ax.set_rticks([0.5, 1, 1.5, 2])  # less radial ticks
ax.set_rlabel_position(-22.5)  # get radial labels away from plotted line
ax.grid(True)
ax.set_title("Polar Coordinate", va='bottom')

# projection= [‘aitoff’, ‘hammer’, ‘lambert’, ‘mollweide’, ‘polar’, ‘rectilinear’]
ax = plt.subplot(122, projection='rectilinear')
ax.plot(x, y,'r',alpha=0.5)
ax.plot(x[60],y[60],'ro')
plt.xlim(-2,2)
plt.ylim(-2.5,2.5)
ax.grid(True)

ax.set_title("Cartesian Coordinate", va='bottom')

plt.tight_layout()                          # Tight the layout
plt.show()

# %% [markdown]
# ### Ch5 Solving and Graphing Linear Inequalities

# %% [markdown]
# ### Ch 6 Systems of Equations and Inequalities

# %% [markdown]
# ### Ch 7 Exponents and Exponential Functions

# %% [markdown]
# ### Ch 8 Polynomials and Factoring

# %% [markdown]
# ### Ch 9 Quadratic Equaltions and Functions
# #### Quadratic Functions: 二次函數
# Quadratic means "四邊形"。命名時可能是要算四邊形面積使用，但是實際上只有二次方。
#
# (三次函數：Cubic Function, 四次函數：Quartic Function.)
#
# Quadratic Function:
# $y = a x^2 + b x + c$ , where a is not 0.
#
# Cubic Function:
# $y = a x^3 + b x^2 + c x + d$ , where a is not 0.
#
# Quartic Function:
# $y = a x^4 + b x^3 + c x^2 + d x + e$ , where a is not 0.

# %%
################################################################################
# Let's see the linear functions in XY plane
# Author: stevenlee, tw.steven@gmail.com
# Date: 2017.05.16
################################################################################
# Import necessary modules:
# Numpy is for fundamental science computing. http://www.numpy.org/
# Matplotlib is for generating figures. https://matplotlib.org/
import numpy as np
import matplotlib.pyplot as plt

# Prepare the data x = [-10 -9.9 -9.8 ... -0.1 0, 0.1 ... 9.8 9.9]
x = np.arange(-10., 10., 0.1) # ask np to generate an array from -10 to 10, with step 0.1 (start, stop, step)

# Prepare different output data
y_constant = 0*x + 5                          # horizontal line y = 5
y_linear = 2*x                                # y = 2x
y_quadric = (x**2) - 2*x - 10.                # y = x^2 - 2x - 10
y_cubic = (x-4)*(x+8)*(x-6)                   # a cubic function with root at 4,6,-8
y_quartic = (x-4)*(x+8)*(x-8)*(x+6)           # a quartic function with root at 4,-8,8,-6


# Plot to figure
plt.figure(figsize=(8, 6), dpi=80)
plt.subplot(221)                              # A plot with 2x2 subplots, now plot the first
plt.title('Constant and Linear')              # Title of 1st subplot
plt.plot(x, y_constant,'r',x, y_linear, 'g')  # Plota red line and green line
plt.grid(True)                                # Turn on the grid
plt.ylabel('output(y)')                       # Y Label

plt.subplot(222)
plt.title('Linear and Quadric')
plt.plot(x, y_linear,'g',x, y_quadric, 'b')
plt.grid(True)

plt.subplot(223)
plt.title('Quadric and Cubic')
plt.plot(x, y_quadric,'b',x, y_cubic, 'r')
plt.grid(True)
plt.xlabel('input(x)')
plt.ylabel('output(y)')

plt.subplot(224)
plt.title('Cubic and Quartic')
plt.plot(x, y_cubic,'r',x, y_quartic, 'k')
plt.grid(True)
plt.xlabel('input(x)')

plt.tight_layout()                          # Tight the layout
plt.show()                                  # Show the plot

# %% [markdown]
# ### Ch 10 Data Analysis
# ### Ch 11 Probability
