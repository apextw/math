# %% [markdown]
# # Algebra 2
# #### High School Algebra Study Note

# %% [markdown]
# ### Ch0
#
# ##### Complex Number
#
# We don't know the solution of $x^2 + 1 = 0$, so we define the solution is i. That is:
#
# $i = \sqrt{-1}$
#
# $i^2 = -1$
#
# i stand for imaginary. Sometimes, we use j instead of i. (Too many kings named as "Louies" makes you confuse. i used as current in science, as index in programming...)
#
# Is it all?
#
# To understand complex number, first we need to know:
# 1. Complex number is not complex, it's general
# 2. Imaginary is not imaginary
#
# Complex number is a pair of number, like (a,b). It has two parts, "real part" and "imaginary part". Don't worry, it is just a name. Let's call imaginary part the "side part". The side part is always there, we just don't see it before 16 century.
#
# Let write down with clear notation: $(x+yj) or (x,y)$, the "+" here means nothing, just put them together.
#
# $(a+bj) + (c+dj) = (a+c) + (b+d)j$
#
# $(a+bj) \times (c+dj) = (ac-bd) + (ad+bc)j$
#
# Let's check it:
#
# $1 \times 2 = (2-0) + 0j$
#
# $1 \times 2j = 0 + 2j$
#
# $j \times 2j = -2 + 0j$
#
# It tells us:
# 1. Complex number is in a plane, we call it z plane for complex number x + yj
# 2. Real number is just a line in the plane when y = 0
#
# Why so bother? Since $j^2 = -1$ is so easy to use.
#
# **Because complex number is so good, that they want to use complex number in Algebra!!!**

# %% [markdown]
# ### Ch1. Quadratic Functions and Factoring
#
# #### What is a "Function"?
#     If you have an input x and an output y, then we may say y is function of x. And write as $ y = 𝑓(x) $
#
# #### Quadratic Functions: 二次函數
#     Quadratic means "四邊形"。命名時可能是要算四邊形面積使用，但是實際上只有二次方。三次函數：Cubic Function, 四次函數：Quartic Function.
#
#
# Constant Function:
# $y = a$
#
# Linear Function:
# $ y = ax $
#
# Quadratic Function:
# $y = a x^2 + b x + c$ , where a is not 0.
#
# Cubic Function:
# $y = a x^3 + b x^2 + c x + d$ , where a is not 0.
#
# Quartic Function:
# $y = a x^4 + b x^3 + c x^2 + d x + e$ , where a is not 0.

# %%
################################################################################
# Let's see the functions in XY plane
# Author: stevenlee, tw.steven@gmail.com
# Date: 2017.05.16
################################################################################
# Import necessary modules:
# Numpy is for fundamental science computing. http://www.numpy.org/
# Matplotlib is for generating figures. https://matplotlib.org/
import numpy as np
import matplotlib.pyplot as plt

# Prepare the data
x = np.arange(-10., 10., 0.1) # ask np to generate an array from -10 to 10, with step 0.1 (start, stop, step)

# Prepare different output data
y_constant = 0*x + 5
y_linear = 2*x
y_quadric = (x**2) - 2*x - 10
y_cubic = (x-4)*(x+8)*(x-6)
y_quartic = (x-4)*(x+8)*(x-8)*(x+6)


# Plot to figure
plt.subplot(221)
plt.title('Constant and Linear')
plt.plot(x, y_constant,'r',x, y_linear, 'g')
plt.grid(True)
plt.ylabel('output(y)')

plt.subplot(222)
plt.title('Linear and Quadric')
plt.plot(x, y_linear,'g',x, y_quadric, 'b')
plt.grid(True)

plt.subplot(223)
plt.title('Quadric and Cubic')
plt.plot(x, y_quadric,'b',x, y_cubic, 'r')
plt.grid(True)
plt.xlabel('input(x)')
plt.ylabel('output(y)')

plt.subplot(224)
plt.title('Cubic and Quartic')
plt.plot(x, y_cubic,'r',x, y_quartic, 'k')
plt.grid(True)
plt.xlabel('input(x)')

plt.tight_layout()
plt.show()

# %%
################################################################################
# Let's see Quadric function's components
# Author: stevenlee, tw.steven@gmail.com
# Date: 2017.05.16
################################################################################
# Import necessary modules:
import numpy as np
import matplotlib.pyplot as plt

# Prepare the data
x = np.arange(-10., 10., 0.1) # ask np to generate an array from -10 to 10, with step 0.1 (start, stop, step)

y0 = 0*x + 50
y1 = 10*x
y2 = (x**2)
y_quardric = y2 + y1 + y0


# Plot to figure
plt.title('Quadric Function is made by 3 components')
plt.plot(x, y_quardric, 'b',linewidth=2.0)
plt.plot(x, y2,'g', x, y1, 'r', x, y0, 'y', alpha=0.7)
plt.text(-5,120,'Blue = Green + Red + Yellow')
plt.xlabel('input(x)')
plt.ylabel('output(y)')
plt.grid(True)
plt.show()

# %%
################################################################################
# Let's see Quadric function's parameters
# Author: stevenlee, tw.steven@gmail.com
# Date: 2017.05.16
################################################################################
# Import necessary modules:
import numpy as np
import matplotlib.pyplot as plt

# Prepare the data
x = np.arange(-10., 10., 0.1) # ask np to generate an array from -10 to 10, with step 0.1 (start, stop, step)

y0 = 0*x + 20
y1 = -5*x
y2 = (x**2)
y_q1 = y2 + y1 + y0
y_q2 = -y2 + y1 + y0
y_q3 = y2 - y1 + y0
y_q4 = y2 + y1 - y0
y_q5 = 2*y2 + y1 + y0


# Plot to figure
plt.subplot(221)
plt.title('Flip the 2nd order part')
plt.plot(x, y_q1, 'b',x, y_q2, 'g')
plt.text(-8,-50,'$y = -ax^2 + bx + c$')
plt.grid(True)

plt.subplot(222)
plt.title('Flip the 1st order part')
plt.plot(x, y_q1, 'b',x, y_q3, 'g')
plt.text(-2,140,'$y = ax^2 - bx + c$')
plt.grid(True)

plt.subplot(223)
plt.title('Flip the Constant part')
plt.plot(x, y_q1, 'b',x, y_q4, 'g')
plt.text(-8,-40,'$y = ax^2 + bx - c$')
plt.grid(True)

plt.subplot(224)
plt.title('Double the 2nd order parameter')
plt.plot(x, y_q1, 'b',x, y_q5, 'g')
plt.text(-5,150,'$y = 2ax^2 + bx +c$')
plt.grid(True)

# plt.xlabel('input(x)')
# plt.ylabel('output(y)')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Vertex Form
#     If we know the vertex is (h,k), we may write:
# $$y = a(x-h)^2 + k$$
#
#     The vertex is (h,k), the axis of symmetry is: x = h
#
# #### Intercept Form
#     If we know interception points (a,0) and (b,0), we may write:
# $$y = c(x-a)(x-b)$$
#
# #### Factoring:
#     Factoring is to find intercept form. (x-k) is a factor.
#
# $$ y = (x+a)(x+b) $$
#
# $$ y = x^2 + (a+b)x + ab $$
#
# For example $ y = x^2 + 7x + 12 = (x+3)(x+4)$
#
#
# ##### Practice:
# $x^2 - 9 = (x-3)^2$
#
# $x^2 + 4x + 4 = (x+2)^2$
#
# $x^2 - 4x + 4 =(x-2)^2$
#
# ##### Hint:
# $ a^2 - b^2 = (a+b)(a-b) $
#
# $ a^2 + 2ab + b^2 = (a+b)^2 $
#
# $ a^2 - 2ab + b^2 = (a-b)^2 $
#
#
# #### Question: We always have vertex form for an $y = ax^2+bx+c$ equation? Why?
#
# #### Question: We always have intercept form for an $y = ax^2+bx+c$ equation? Why?

# %%
################################################################################
# Let's see Quadric function's root
# Author: stevenlee, tw.steven@gmail.com
# Date: 2017.05.16
################################################################################
import numpy as np
import matplotlib.pyplot as plt

# Prepare the data
x = np.arange(-10., 10., 0.1) # ask np to generate an array from -10 to 10, with step 0.1 (start, stop, step)

y_zero = 0*x
y_q1 = (x-5)*(x+5)
y_q2 = (x-5)*(x+5) + 30
y_q3 = (x**2)

# Plot to figure
plt.title('Root mean f(x) cross zero')
plt.plot(x, y_q1, 'b',x, y_q2, 'g',x, y_q3, 'r')
plt.plot(x, y_zero,'m')
plt.text(-2,20,'$y = f(x)$')
plt.text(-7,-10,'$y = 0$')
plt.xlabel('input(x)')
plt.ylabel('output(y)')
plt.grid(True)
plt.show()

# %% [markdown]
# #### 1.8 Use the Quadratic Formula
#
# Let a,b,c are real number, such that a≠0. The quadratic function is $y = ax^2 + bx + c $
#
# To solve the function, we let y = 0, that is $ax^2 + bx + c = 0 $
#
# The we may have $ x = \frac{-b ± \sqrt{b^2-4ac} }{2a}$
#
# Here, we say D, the "Discriminant" for quadratic function, is $b^2-4ac$
# - If D > 0 : Two real root
# - If D = 0 : Same root
# - If D < 0 : No real root
#
# ##### Question: What does it means "No real root"? Considering the imaginary part, where is the root exactly be?

# %% [markdown]
# ##### Addition Material: What "No real root" really means...
#
# We already have a quadratic function $y = ax^2 + bx + c$
#
# Now we rewrite it as: $y = aw^2 + bw + c$, where $w = x + jz$
#
# $$y = a(x + jz)^2 + b(x + jz) + c = a(x^2 - z^2 +2jxz) + b(x + jz) + c$$
#
# $$y = ax^2 + bx + (c-az^2) + j(2xy+bz)$$
#
# Good! We know that z = 0 is just a special case.
# If z = 0, $y = ax^2 + bx + c$ .
#
#
# Let's check an example: $a = 1, b = 0, c = 4$
#
# As $(b^2-4ac) < 0 \to $ There is no "Real Root"
#
# Let's play with complex number:
#
# $y = (x+jz)^2 + 4$
#
# $y = x^2 - z^2 + 4 + jxz$
#
# Root means y = 0, that is 0 in real part, and 0 in imaginary part (y = 0 + 0j)
#
# Imaginary part: $xz = 0$
#
# Real part: $(x+jz)^2 + 4 = x^2 - z^2 + 4 = 0$
#
# We may infer:
# 1. x = 0 or z = 0 (Come from xz=0)
# 2. When x = 0, then z = ±2; When z = 0, then x = 2j, which is not "real", so z≠0
#
# So, we have roots: 2j and -2j
# Let's see what happened by figure:

# %%
################################################################################
# Let's see Quadric function when discriminant < 0
# Author: stevenlee, tw.steven@gmail.com
# Date: 2017.05.16
################################################################################
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d

# Prepare the data
x = []
z = []
l = np.arange(-5., 5., 1)
length = len(l)
for i in range(length):
    x.append(l)

x = np.asarray(x)
x.reshape((length,length))
z = np.transpose(x)

y = x**2 - z**2 +4
y_real = x**2 +4
y_z2 = x**2 - 4 +4  # z^2 = 4

# y_im = np.multiply(x,z)
y_zero = x*0


# Plot to figure
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plane y = x**2 + z**2 + 4
ax.plot_wireframe(x, z, y,color='g', rstride=1, cstride=1,alpha=0.5)
# Line y = x**2 + 4, z = 2
ax.plot_wireframe(x, (y_zero+2), y_z2,color='g', rstride=1, cstride=1, linewidth=2)
# Line y = x**2 + 4, z = -2
ax.plot_wireframe(x, (y_zero-2), y_z2,color='g', rstride=1, cstride=1, linewidth=2)


# Plane z = 0
ax.plot_surface(x, y_zero, (z*5+10),color='r', alpha=0.25)
# Line y = x**2 + 4, z = 0
ax.plot_wireframe(x, y_zero, y_real,color='r', rstride=1, cstride=1, linewidth=2)


# Plane y = 0
ax.plot_surface(x, z, y_zero,color='y', alpha = 0.25)
# Line z = 0, y = 0
ax.plot_wireframe(x, y_zero, y_zero,color='y', linewidth=2)
# Line z = 2, y = 0
ax.plot_wireframe(x,(y_zero+2), y_zero,color='y', linewidth=2)
# Line z = -2, y = 0
ax.plot_wireframe(x,(y_zero-2), y_zero,color='y', linewidth=2)


ax.set_xlabel('x')
ax.set_ylabel('z (Imaginary part of input)')
ax.set_zlabel('Re(y)')
ax.view_init(elev=20, azim=50)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Ch2. Polynomials and Polynominal Fuctions
#
# Poly means Multiple, nominal means Term. Polynominal means "Many terms"
#
# Polynominal Fuctions $y = a_{n}x^n + a_{n-1}x^{(n-1)} + ... + a_{0}$
#
# Polynominal Function is also called as algebraic function. That means:
# 1. It has limited items (Not infinity)
# 2. It used only algebraic operations: $+ - \times \div $ and "rational exponentiation" (for example $x^{2/3}$)
#
# We call "Not Polynominal functions" as Transcendental function (超越函數)
# * $x^{\pi}$ (Irrational exponentiation)
# * $log_10(x)$ (logarithm)
# * $sin(x)$ (periodic function)
#
# Now, we know a "function" $f()$ is something(x) in and something(y) out. $y=f(x)$. Some funcions have algebraic properties, and some don't. Polynominal functions have algebraic properties and can do algebraic operation.
#
# ** What is algebraic property? **
# - Commutativity (交換律)
# - Associativity (結合律)
#
# ##### Hint
#
# $a^3 + b^3 = (a+b)(a^2-ab+b^2) $
#
# $a^3 - b^3 = (a-b)(a^2+ab+b^2) $
#
#
# ##### Polynominal long division (長除法)
#
# ##### Rational zero theorem
# Rational zeros are the possible roots
#
# ##### Turning point
#
# Turning point means slope = 0, or local maximum/minimum.
#
# n-th order polynominal has (n-1) turning point

# %% [markdown]
# ### Ch3. Rational Exponents and Radical Functions
#
# #### Rational Exponents
#
# Addition $ a^{m+n} = a^{m} \cdot a^{n}$
#
# Subtraction $ a^{m-n} = \frac{a^{m}}{a^{n}}, a≠0$
#
# Multiplication $(a^{m})^n = a^{m \cdot n}$
#
# Division $a^{1/n} = \sqrt[n]{a} $
#
# $a^{m/n} = (a^{1/n})^{m} = (\sqrt[n]{a})^{m} $
#
# $a^{-m/n} = \frac{1}{(a^{1/n})^{m}} = \frac{1}{(\sqrt[n]{a})^{m}} , a≠0$
#
#
# #### Operation of function
#
# Addition $h(x) = f(x) + g(x) $
#
# Subtraction $h(x) = f(x) - g(x) $
#
# Multiplication $h(x) = f(x) \cdot g(x) $
#
# Division $h(x) = \frac{f(x)}{g(x)} $
#
# Composition $h(x) = g(f(x))$
#
# ** What is Composition g(f(x)) means? **
#
# Feed the output of f(x) to g(x). Cascaded the two function: $ x \to f() \to g() \to y $
#
# If $f(x) = x-3$, $g(x) = x^2 + 2$ then
#
# $ h(x) = g(f(x)) = (f(x))^2+2 = (x-3)^2+2 = x^2 - 6x + 11 $

# %% [markdown]
# #### Inverse Function
#
# A function describes the relationship of input and output. Inverse function means "given the output, you may get the input".
#
# $f^{-1}(x)$ is the inverse function of $f(x)$
#
#
# ##### How to get $f^{-1}$ ?
#
#     Step 1: replace y by x, and replace x by y
#     Step 2: re-arrange it as y = ...
#
#
# ##### Check the composition of inverse function is x: $ f(f^{-1}(x)) = x $
#
# For example, $y = f(x) = x^3$
#
# Step 1: $x = y^3$
#
# Step 2: $y = x^{1/3}$, So the $f^{-1}(x) = \sqrt[3]{x}$

# %%
################################################################################
# Let's see a Inverse Function
# Author: stevenlee, tw.steven@gmail.com
# Date: 2017.05.18
################################################################################
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(-10.0, 10., 0.1)

f = (x**3)/10
g = ((10*abs(x))**(1/3)) * (x/abs(x))

# Plot to figure
plt.title('Inverse function')
plt.plot(x, f, 'b',label='$y=x^{3}/10$')
plt.plot(x, g, 'g',label='$y=(10^{1/3})x^{1/3}$')
plt.plot(x, x, 'r--',label='$y=x$',alpha=0.5)
plt.xlabel('x')
plt.ylabel('y')
plt.xlim([-10,10])
plt.ylim([-10,10])
plt.legend(loc=2)
plt.grid(True)
plt.show()

# %% [markdown]
# #### Radical Functions
#
# For example: $ y = \sqrt[3]{(x^2-1)}$

# %%
################################################################################
# Let's see a Radical Function
# Author: stevenlee, tw.steven@gmail.com
# Date: 2017.05.18
################################################################################
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(-5., 5., 0.1)

sign = (x/abs(x))

p = abs(x)**(2/3) * sign
q = (abs(x)**0.5) * sign

# Plot to figure
plt.title('Rational function')
plt.plot(x, x, 'b',alpha=0.5)
plt.plot(x, p, 'g',label='$y=x^{2/3}$')
plt.plot(x, q, 'r',label='$y=x^{0.5}$')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc=2)
plt.grid(True)
plt.show()

# %% [markdown]
# ### Ch4. Exponential and Logarithmic Functions
#
# #### Exponential Functions

# %%
################################################################################
# Let's see a Exponential Growth Function
# Author: stevenlee, tw.steven@gmail.com
# Date: 2017.05.18
################################################################################
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import factorial

x = np.arange(-1., 4., 0.1)

p = x**x
q = np.exp(x)
r = x**4
n = factorial(x)

# Plot to figure
plt.title('Rational function')
plt.plot(x, p, 'b',label='$y=x^x$')
plt.plot(x, q, 'g',label='$y=e^x$')
plt.plot(x, r, 'r',label='$y=x^4$')
plt.plot(x, n, 'm',label='$y=x!$')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc=2)
plt.grid(True)
plt.show()

# %%
################################################################################
# Let's see a Exponential Decay Function
# Author: stevenlee, tw.steven@gmail.com
# Date: 2017.05.18
################################################################################
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(-5., 5., 0.2)

p = (0.5)**x
q = - p
r = (0.6)**x

# Plot to figure
plt.title('Exponential Decay function')
plt.plot(x, p, 'b',label='$y=0.5^x$')
plt.plot(x, q, 'g',label='$y=-0.5^x$')
plt.plot(x, r, 'r',label='$y=0.6^x$')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc=2)
plt.grid(True)
plt.show()

# %% [markdown]
# #### 4.3 e, the natural base
# e is the natural base or called the **Euler number**. The discovery of the constant itself is credited to Jacob Bernoulli in 1683. He wrote:
#
# $e = lim_{n \to \infty}(1 + \frac{1}{n})^n$
#
# or, using Binomial theorem, we may also get:
#
# $e = \sum_{n=0}^{\infty}\frac{1}{n!}$
#
# ##### Factorial (n!)
#
# Definition: $n! = n \cdot (n-1)!$ , n is positive integer
#
# $1! = 1 \cdot 0!$, for consistency, we need to define 0! = 1
#
# The function $f(x) = e^x$ is called the natural exponential function. The natural logarithm, or logarithm to base e, $g(x)=log_e(x)$, is the inverse function to the natural exponential function.

# %%
################################################################################
# Let's see a Euler number
# Author: stevenlee, tw.steven@gmail.com
# Date: 2017.05.18
################################################################################
import numpy as np
import matplotlib.pyplot as plt

n = np.arange(1., 100., 2)

y = (1 + (1/n))**n
p = 0*n + np.e

# Plot to figure
plt.title('Euler Number $(1+(1/n))^n$')
plt.plot(n, y, 'g',label='$y=(1+(1/n))^n$ ')
plt.plot(n, p, 'r',alpha=0.5)
plt.xlabel('n')
plt.ylabel('y')
plt.legend(loc=5)
plt.grid(True)
plt.show()

# %% [markdown]
# #### Logarithmic Functions
#
# If $f(x) = b^x$, the inverse function $f^{-1}(x)=log_b(x)$, logarithm of x with base b, or we say "log base b of x"
#
# For example,
#
# $ 2^3 = 8 \to log_2(8) = 3$
#
# ##### Logarithm properties
# - Product property: $log_b(mn) = log_b(m) + log_b(n)$
# - Quotient property: $log_b(\frac{m}{n}) = log_b(m) - log_b(n)$
# - Power property: $log_b(m^n) = n \cdot log_b(m)$
#
# ##### $log_b(0) \to -\infty$
#
# $log_b(0)$ is not defined. Because there is no y meets $b^y = 0$
#
# But, if we say $b^y \to 0$, then, $log_b(0) \to -\infty$
#
# ##### $log_b(1) = 0$
#
# Because $b^0 = 1$, logarithm function always pass point (1,0)

# %%
################################################################################
# Let's see a Logarithmic Function
# Author: stevenlee, tw.steven@gmail.com
# Date: 2017.05.18
################################################################################
import numpy as np
import matplotlib.pyplot as plt

step = 0.1 # give smaller step, one x will close to 0, log(0) -> -inf

x = np.arange(-1., 4., step)

p = 0*x
q = np.log(x)
r = np.log10(x)
s = np.log2(x)

# Plot to figure
plt.title('Logarithmic function')
plt.plot(x, p, 'b',alpha=0.5)
plt.plot(x, s, 'm',label='$y=log_{2}(x)$')
plt.plot(x, q, 'g',label='$y=ln(x)$')
plt.plot(x, r, 'r',label='$y=log_{10}(x)$')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc=4)
plt.grid(True)
plt.show()

# %% [markdown]
# ### Ch5. Rational Functions
# A rational function is any function which can be defined by a rational fraction.
#
# $f(x) = \frac{P(x)}{Q(x)}$
#
# ** Notice: What happened when the denominator equals 0 **
#
# #### Properties
# - Addition
# - Subtraction
# - Multiplication
# - Division
# (with no surprise~)
#
# #### Variation
# Direct variation: $y = kx, k≠0$
# Inverse variation $y = \frac{k}{x}, k≠0$
# Joint variation: $z = kxy$, z varies jointly with x and y

# %%
################################################################################
# Let's see the direct and inverse variation
# Author: stevenlee, tw.steven@gmail.com
# Date: 2017.05.18
################################################################################
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0.1, 5., 0.1)
y_dir = 2*x
y_inv = 2 / x

# Plot to figure
plt.title('Variations')
plt.plot(x, y_dir, 'g',label='Direct variation')
plt.plot(x, y_inv, 'r',label='Inverse variation')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc=1)
plt.grid(True)
plt.show()

# %%
################################################################################
# Let's see the joint variation
# Author: stevenlee, tw.steven@gmail.com
# Date: 2017.05.18
################################################################################
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d

# Prepare the data
x = []
y = []
l = np.arange(-10., 10., 1)
length = len(l)
for i in range(length):
    x.append(l)

x = np.asarray(x)
x.reshape((length,length))
y = np.transpose(x)

# Joint variation function z = xy
z = x * y 

# Plot to figure
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plane z = xy
ax.plot_wireframe(x, y, z,color='g', rstride=1, cstride=1,alpha=0.5)

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.view_init(elev=15, azim=-25)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Solve the equation
# Wait a minute, what is "Solve"?
#
# Let's solve the equation x + 3 = 3x -1 ?
# Simple, 4 = 2x, so, x = 2. Solved!
#
# Let's see the two lines:
#
# $y_1 = x + 3$
#
# $y_2 = 3x -1$
#
# The solution is the cross point of the two lines!
# "Cross" means: You have same outputs when inputs are the same.
#
# One solution means **"only one cross point"**.
#
# That implies:
# - Sometimes, you have no solution
# - Sometimes, you have 2 or more solutions
# - Sometimes, your solution is another equation (infinite number)

# %%
################################################################################
# Let's solve the equation
# Author: stevenlee, tw.steven@gmail.com
# Date: 2017.05.18
################################################################################
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(-5., 5., 0.1)
y1 = x + 3
y2 = 3*x -1

# Plot to figure
plt.title('Solve an equation')
plt.plot(x, y1, 'g',label='$y=x+3$')
plt.plot(x, y2, 'r',label='$y=3x-1$')
plt.text(2,3,'cross at (2,5)')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc=4)
plt.grid(True)
plt.show()

# %% [markdown]
# #### Even function and Odd function
#
# Even function: $f(-x) = f(x)$
#
# Odd function: $f(-x) = -f(x)$
#
# Let's check the "Symmetry Axis". What do you find?

# %%
################################################################################
# Let's see even and odd function
# Author: stevenlee, tw.steven@gmail.com
# Date: 2017.05.18
################################################################################
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(-5., 5., 0.1)
y_even = (x**4 - 20*(x**2)) / 30
y_oddp = (2*(x**3) - 18*x) / 30
y_oddn = (2*((-x)**3) - 15*(-x)) / 30

zero = 0*x

# Plot to figure
plt.title('Even and Odd function')

# Even function
plt.plot(x, y_even, 'g',label='$f_{even}(x)$',linewidth=2)

# Odd functions
plt.plot(x, y_oddp, 'r',label='$f_{odd}(x)$',linewidth=1)
plt.plot(x, y_oddn, 'r',label='$f_{odd}(-x)$',linewidth=1,alpha=0.5)

# Plot horizontal and vertical line for reference
plt.plot(zero, x, 'g',alpha=0.25)
plt.plot(x, zero, 'r',alpha=0.25)

# Plot the points on even function
plt.plot(4.75, 2, 'go')
plt.plot(-4.75, 2, 'go')
# Plot the points on odd function
plt.plot(2, -0.63, 'ro')
plt.plot(-2, 0.63, 'ro')

plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc=8)
plt.grid(True)
plt.show()

# %% [markdown]
# #### Asymptote

# %%
################################################################################
# Let's see a Rational Function
# Author: stevenlee, tw.steven@gmail.com
# Date: 2017.05.18
################################################################################
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(-5., 5., 0.1)

p = (x**3) - (2*x)
q = (x**2 -5)
y = 2*p / q

# Plot to figure
plt.title('Rational function')
plt.plot(x, y, 'b',label='$P(x)/Q(x)$')
plt.plot(x, p, 'g',label='$P(x)$')
plt.plot(x, q, 'r',label='$Q(x)$')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc=4)
plt.grid(True)
plt.show()

# %% [markdown]
# ### Ch6. Data Analysis and Statistics
#
# ### Ch7. Sequence and Series
#
# ### Ch8. Quadratic Relations and Conic Sections
#
# ### Ch9. Trigonometric Ratios and Functions
#
# ### Ch10. Trigonometric Graphs, Identities and Equations
